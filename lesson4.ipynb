# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Instalação das bibliotecas
import numpy as np
import pandas as pd
import openpyxl

# %%
# name_of_df = pd.read_csv("data Location or path/file_name.file_ext")
new_df = pd.read_csv(r"C:\Users\user\Documents\international_migration_citizenship.csv")
new_df
# Out:
#        year_month month_of_release     passenger_type direction citizenship  \
# 0         2001-09          2020-09  Long-term migrant  Arrivals          NZ
# 1         2002-03          2020-09  Long-term migrant  Arrivals          NZ
# 2         2005-01          2020-09  Long-term migrant  Arrivals          NZ
# 3         2005-04          2020-09  Long-term migrant  Arrivals          NZ
# 4         2005-07          2020-09  Long-term migrant  Arrivals          NZ
# ...           ...              ...                ...       ...         ...
# 338517    2024-03          2024-07  Long-term migrant  Arrivals      non-NZ
# 338518    2024-04          2024-07  Long-term migrant  Arrivals      non-NZ
# 338519    2024-05          2024-07  Long-term migrant  Arrivals      non-NZ
# 338520    2024-06          2024-07  Long-term migrant  Arrivals      non-NZ
# 338521    2024-07          2024-07  Long-term migrant  Arrivals      non-NZ
#
# ...

# %%
# you may get unicode error: add r or make all the back slases forward

# %%
new_ec = (pd.read_csv('C:/Users/user/Documents/effects_of_covid_19.csv'))
new_ec
# Out:
#         Direction  Year        Date    Weekday Country Commodity  \
# 0         Exports  2015  01/01/2015   Thursday     All       All
# 1         Exports  2015  02/01/2015     Friday     All       All
# 2         Exports  2015  03/01/2015   Saturday     All       All
# 3         Exports  2015  04/01/2015     Sunday     All       All
# 4         Exports  2015  05/01/2015     Monday     All       All
# ...           ...   ...         ...        ...     ...       ...
# 111433  Reimports  2021  11/12/2021   Saturday     All       All
# 111434  Reimports  2021  12/12/2021     Sunday     All       All
# 111435  Reimports  2021  13/12/2021     Monday     All       All
# 111436  Reimports  2021  14/12/2021    Tuesday     All       All
# 111437  Reimports  2021  15/12/2021  Wednesday     All       All
#
#        Transport_Mode Measure      Value  Cumulative
# 0                 All       $  104000000   104000000
# 1                 All       $   96000000   200000000
# ...

# %%
assault_data = pd.read_excel("C:/Users/user/Documents/analysis_public_sexual_assaults_and_robberies.xlsx")
assault_data
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# ...     ...                  ...                              ...
# 2015   2016               506653                        Riverhead
# 2016   2017               610601                         Grasmere
# 2017   2018               536513                   Bethlehem East
# 2018   2019               574302                        Te Kainga
# 2019   2020               527007                    Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# ...

# %%
new_df.head()
# Out:
#   year_month month_of_release     passenger_type direction citizenship  \
# 0    2001-09          2020-09  Long-term migrant  Arrivals          NZ
# 1    2002-03          2020-09  Long-term migrant  Arrivals          NZ
# 2    2005-01          2020-09  Long-term migrant  Arrivals          NZ
# 3    2005-04          2020-09  Long-term migrant  Arrivals          NZ
# 4    2005-07          2020-09  Long-term migrant  Arrivals          NZ
#
#                          visa country_of_residence  estimate  standard_error  \
# 0  NZ and Australian citizens          Afghanistan         1               0
# 1  NZ and Australian citizens          Afghanistan         3               0
# 2  NZ and Australian citizens          Afghanistan         5               0
# 3  NZ and Australian citizens          Afghanistan         1               0
# 4  NZ and Australian citizens          Afghanistan         1               0
#
#   status
# 0  Final
# 1  Final
# 2  Final
# 3  Final
# 4  Final

# %%
new_df[10:20] #Last range is excluded
# Out:
#    year_month month_of_release     passenger_type direction citizenship  \
# 10    2006-07          2020-09  Long-term migrant  Arrivals          NZ
# 11    2006-08          2020-09  Long-term migrant  Arrivals          NZ
# 12    2006-09          2020-09  Long-term migrant  Arrivals          NZ
# 13    2006-11          2020-09  Long-term migrant  Arrivals          NZ
# 14    2006-12          2020-09  Long-term migrant  Arrivals          NZ
# 15    2007-01          2020-09  Long-term migrant  Arrivals          NZ
# 16    2007-07          2020-09  Long-term migrant  Arrivals          NZ
# 17    2007-08          2020-09  Long-term migrant  Arrivals          NZ
# 18    2007-10          2020-09  Long-term migrant  Arrivals          NZ
# 19    2007-12          2020-09  Long-term migrant  Arrivals          NZ
#
#                           visa country_of_residence  estimate  standard_error  \
# 10  NZ and Australian citizens          Afghanistan         1               0
# ...

# %%
new_df.columns
# Out:
# Index(['year_month', 'month_of_release', 'passenger_type', 'direction',
#        'citizenship', 'visa', 'country_of_residence', 'estimate',
#        'standard_error', 'status'],
#       dtype='object')

# %%
new_df.index
# Out:
# RangeIndex(start=0, stop=338522, step=1)

# %%
new_df.tail()
# Out:
#        year_month month_of_release     passenger_type direction citizenship  \
# 338517    2024-03          2024-07  Long-term migrant  Arrivals      non-NZ
# 338518    2024-04          2024-07  Long-term migrant  Arrivals      non-NZ
# 338519    2024-05          2024-07  Long-term migrant  Arrivals      non-NZ
# 338520    2024-06          2024-07  Long-term migrant  Arrivals      non-NZ
# 338521    2024-07          2024-07  Long-term migrant  Arrivals      non-NZ
#
#         visa country_of_residence  estimate  standard_error       status
# 338517  Work             Zimbabwe        16               1  Provisional
# 338518  Work             Zimbabwe        19               1  Provisional
# 338519  Work             Zimbabwe        13               1  Provisional
# 338520  Work             Zimbabwe        21               1  Provisional
# 338521  Work             Zimbabwe        12               1  Provisional

# %%
# write df as csv or excel

# %%
assault_data.to_csv("C:/Users/user/Documents/save_newdf.csv")
